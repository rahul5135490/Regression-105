# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\control chart\\work sheet.xlsx")

# %%
df.head()
# Out:
#    Time  observed value  upper limit  mid value  lower limit
# 0     1              59           70         45           20
# 1     2              55           70         45           20
# 2     3              59           70         45           20
# 3     4              88           70         45           20
# 4     5              49           70         45           20

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df.plot(x="Time", y="observed value",kind="line", marker="o")
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
plt.ylabel("Observed value")
# Out:
# Text(0, 0.5, 'Observed value')

# %%
plt.hlines(y=70, xmin=1, xmax=7, colour="r",label="pre-intervention")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d5f00127686f> in <module>
# ----> 1 plt.hlines(y=70, xmin=1, xmax=7, colour="r",label="pre-intervention")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    2709         y, xmin, xmax, colors=None, linestyles='solid', label='', *,
#    2710         data=None, **kwargs):
# -> 2711     return gca().hlines(
#    2712         y, xmin, xmax, colors=colors, linestyles=linestyles,
#    2713         label=label, **({"data": data} if data is not None else {}),
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
# ...

# %%
plt.hlines(y=20, xmin=1, xmax=7, colour="r")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7fdf52a103e3> in <module>
# ----> 1 plt.hlines(y=20, xmin=1, xmax=7, colour="r")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    2709         y, xmin, xmax, colors=None, linestyles='solid', label='', *,
#    2710         data=None, **kwargs):
# -> 2711     return gca().hlines(
#    2712         y, xmin, xmax, colors=colors, linestyles=linestyles,
#    2713         label=label, **({"data": data} if data is not None else {}),
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
# ...

# %%
plt.hlines(y=70, xmin=1, xmax=7, colour="r",linestyle="dashed",label="post-intervention")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-981605c39c84> in <module>
# ----> 1 plt.hlines(y=70, xmin=1, xmax=7, colour="r",linestyle="dashed",label="post-intervention")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    2709         y, xmin, xmax, colors=None, linestyles='solid', label='', *,
#    2710         data=None, **kwargs):
# -> 2711     return gca().hlines(
#    2712         y, xmin, xmax, colors=colors, linestyles=linestyles,
#    2713         label=label, **({"data": data} if data is not None else {}),
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
plt.xticks(data["Time"],data["Time"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ee2c3958cdfe> in <module>
# ----> 1 plt.xticks(data["Time"],data["Time"])
#
# NameError: name 'data' is not defined

# %%
plt.legend(bbox_to_anchor=(1.05,1), loc="upper left",borderaxespad=0)
# Out:
# No handles with labels found to put in legend.

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
