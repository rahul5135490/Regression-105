# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
list_s=[1,2,-4,6.6,"data values"]

# %%
print(list_s)
# Out:
# [1, 2, -4, 6.6, 'data values']

# %%
series1= pd.Series(list_s)

# %%
series1
# Out:
# 0              1
# 1              2
# 2             -4
# 3            6.6
# 4    data values
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2= pd.Series([1,2,3,4])

# %%
print(series2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
empty_s = pd.Series([])
# Out:
# <ipython-input-10-7ded7683edcc>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_s = pd.Series([])

# %%
print(empty_s)
# Out:
# Series([], dtype: float64)

# %%
series3 = pd.Series([1,2,3,4], index= ["a","b","c","d"])

# %%
print(series3)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx", nrows=900)

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 895        NaN     NaN           NaT        NaN         NaN        NaN
# 896        NaN     NaN           NaT        NaN         NaN        NaN
# 897        NaN     NaN           NaT        NaN         NaN        NaN
# 898        NaN     NaN           NaT        NaN         NaN        NaN
# 899        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\rcmlp.12

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index([                    'REC_ID',                         'AC',
#                     'REPORTED_DATE',                 'FLEET_TYPE',
#                       'DEFECT_TYPE',                     'DEFECT',
#                       'DEFECT_ITEM',                    'CHAPTER',
#                        'Unnamed: 8',                       'Time',
#                             'month',                'Unnamed: 11',
#                       'Unnamed: 12',                'Unnamed: 13',
#                           'SECTION',           'CAUSE_INDICATION',
#                'CAUSE_DRIVER_ISSUE',                'Unnamed: 17',
#                'DEFECT_DESCRIPTION',                'Unnamed: 19',
#                                   1,                'Unnamed: 21',
#                              'math',                'Unnamed: 23',
#                       'Unnamed: 24',                'Unnamed: 25',
#                      'CAUSE_ACTION',               'CAUSE_SOURCE',
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx", nrows=900,)

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 895        NaN     NaN           NaT        NaN         NaN        NaN
# 896        NaN     NaN           NaT        NaN         NaN        NaN
# 897        NaN     NaN           NaT        NaN         NaN        NaN
# 898        NaN     NaN           NaT        NaN         NaN        NaN
# 899        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.shape
# Out:
# (900, 47)

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 895        NaN     NaN           NaT        NaN         NaN        NaN
# 896        NaN     NaN           NaT        NaN         NaN        NaN
# 897        NaN     NaN           NaT        NaN         NaN        NaN
# 898        NaN     NaN           NaT        NaN         NaN        NaN
# 899        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 895        NaN     NaN           NaT        NaN         NaN        NaN
# 896        NaN     NaN           NaT        NaN         NaN        NaN
# 897        NaN     NaN           NaT        NaN         NaN        NaN
# 898        NaN     NaN           NaT        NaN         NaN        NaN
# 899        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.head(1)
# Out:
#       REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0  1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
#
#    DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  MIS  \
# 0          3.0     72.0        10.2  10.2  ...        NaN            NaN  NaN
#
#     PN   SN PN_DESCRIPTION POSITION  HOURS_INSTALLED CYCLES_INSTALLED  \
# 0  NaN  NaN            NaN      NaN              NaN              NaN
#
#    DAYS_INSTALLED
# 0             NaN
#
# [1 rows x 47 columns]

# %%
df.head(8)
# Out:
#       REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0  1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1  1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2  1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3  1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4  1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# 5  1176039.0  N405KZ    2021-08-26   B747-400       PILOT  1469027.0
# 6  1176041.0  N405KZ    2021-08-29   B747-400    MECHANIC  1428534.0
# 7  1180548.0  N851GT    2021-08-24     B747-8       PILOT  1390014.0
#
#    DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  MIS  \
# 0          3.0     72.0       10.20  10.2  ...        NaN            NaN  NaN
# 1          3.0     72.0       10.22  11.2  ...        NaN            NaN  NaN
# 2          2.0     72.0       10.24  12.2  ...        NaN            NaN  NaN
# ...

# %%
df.tail(5)
# Out:
#      REC_ID   AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE  DEFECT  DEFECT_ITEM  \
# 895     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 896     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 897     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 898     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 899     NaN  NaN           NaT        NaN         NaN     NaN          NaN
#
#      CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  MIS   PN   SN  \
# 895      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 896      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 897      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 898      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 899      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
#
# ...

# %%
df.tail(7)
# Out:
#      REC_ID   AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE  DEFECT  DEFECT_ITEM  \
# 893     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 894     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 895     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 896     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 897     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 898     NaN  NaN           NaT        NaN         NaN     NaN          NaN
# 899     NaN  NaN           NaT        NaN         NaN     NaN          NaN
#
#      CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  MIS   PN   SN  \
# 893      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 894      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# 895      NaN         NaN   NaN  ...        NaN            NaN  NaN  NaN  NaN
# ...

# %%
# handling missing values in python

# %%
df.isnull()
# Out:
#      REC_ID     AC  REPORTED_DATE  FLEET_TYPE  DEFECT_TYPE  DEFECT  \
# 0     False  False          False       False        False   False
# 1     False  False          False       False        False   False
# 2     False  False          False       False        False   False
# 3     False  False          False       False        False   False
# 4     False  False          False       False        False   False
# ..      ...    ...            ...         ...          ...     ...
# 895    True   True           True        True         True    True
# 896    True   True           True        True         True    True
# 897    True   True           True        True         True    True
# 898    True   True           True        True         True    True
# 899    True   True           True        True         True    True
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8   Time  ...  DELAY_HOUR  DELAY_MINUTES  \
# 0          False    False       False  False  ...        True           True
# ...

# %%
df.isnull().sum()
# Out:
# REC_ID                        843
# AC                            843
# REPORTED_DATE                 843
# FLEET_TYPE                    843
# DEFECT_TYPE                   843
# DEFECT                        843
# DEFECT_ITEM                   843
# CHAPTER                       843
# Unnamed: 8                    843
# Time                          843
# month                         843
# Unnamed: 11                   843
# Unnamed: 12                   843
# Unnamed: 13                   843
# SECTION                       843
# CAUSE_INDICATION              843
# CAUSE_DRIVER_ISSUE            847
# Unnamed: 17                   900
# DEFECT_DESCRIPTION            843
# Unnamed: 19                   900
# 1                               0
# Unnamed: 21                     2
# math                          900
# Unnamed: 23                   900
# Unnamed: 24                   900
# Unnamed: 25                   900
# CAUSE_ACTION                  844
# ...

# %%
df.isnull().sum().sum()
# Out:
# 39048

# %%
df.fillna(method="bfill")
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 895        NaN     NaN           NaT        NaN         NaN        NaN
# 896        NaN     NaN           NaT        NaN         NaN        NaN
# 897        NaN     NaN           NaT        NaN         NaN        NaN
# 898        NaN     NaN           NaT        NaN         NaN        NaN
# 899        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx", nrows=875,)

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 870        NaN     NaN           NaT        NaN         NaN        NaN
# 871        NaN     NaN           NaT        NaN         NaN        NaN
# 872        NaN     NaN           NaT        NaN         NaN        NaN
# 873        NaN     NaN           NaT        NaN         NaN        NaN
# 874        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
# cost function = actual value - predicted value
